# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

from PIL import Image
from pathlib import Path
from matplotlib.patches import Rectangle
from scipy.io import loadmat
import cv2
import torch
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import random
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
from torch.cuda.amp import GradScaler, autocast

# %%
import seaborn as sns
import albumentations as A
from tqdm.notebook import tqdm

# %% [markdown]
# ## Load DataFrame with Pathing

# %%
df = pd.read_csv('../data/POC_imagedata.csv')

# %%
df.head()
# Out:
#   Country   Latitude  Longitude                 Pano_Id  \
# 0   Spain  36.477286  -5.880578  mnPCQWYwG-MIUV64ybl23g
# 1   Spain  37.600117  -4.341563  cXqaOBEMHANps9ZENoLozw
# 2   Spain  42.870488  -1.381516  RHuZZGXpb4levD1LK8Wtsw
# 3   Spain  41.296693  -3.603524  si-40KyaaKHFGdvy12nSIg
# 4   Spain  39.024927  -3.977601  wniI8AxaJ2gBC7q1GjV7GQ
#
#                       Path
# 0  data/images/Spain/0000/
# 1  data/images/Spain/0001/
# 2  data/images/Spain/0002/
# 3  data/images/Spain/0003/
# 4  data/images/Spain/0004/

# %%
#df = df.sample(1000)

# %%
Image.open('../' + df.Path.iloc[0] + 'N.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x200 at 0x7F19645E14E0>

# %% [markdown]
# ## Create Train / Validation Sets

# %%
train, val = train_test_split(df, test_size=0.20, stratify=df.Country.values)

# %%
val, test = train_test_split(val, test_size=0.5, stratify=val.Country.values)

# %%
train.shape, val.shape, test.shape
# Out:
# ((2400, 5), (300, 5), (300, 5))

# %%
sns.scatterplot(x='Longitude', y='Latitude', data=val, hue='Country')

# %% [markdown]
# ## Dataset

# %%
MAPPING = {'Spain': 0, # Spain
           'France': 1, # France
           'Italy': 2} # Italy

# %%
def img_to_np(fullpath):
    x = cv2.imread(fullpath).astype(np.uint8)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
def stitch_panos(path, rand):
    direction = ['N', 'E', 'S', 'W']
    rolled = np.roll(direction, rand)
    rolled = np.hstack([rolled, rolled[0]])
    return np.concatenate([img_to_np('../' + path + d + '.jpg') for d in rolled], axis=1)

# %%
def get_xy(path, y_map, rand):
    x = stitch_panos(path, rand)
    y = y_map[path[12: 12 + path[12:].find('/')]]
    return x, y

# %%
x, y = get_xy(train.Path.iloc[0], MAPPING, 1)

# %%
plt.imshow(x)

# %%
x.shape, y
# Out:
# ((200, 1500, 3), 0)

# %% [markdown]
# #### Data Augmentation Functions

# %%
transforms = A.Compose([
        A.RandomCrop(height=150, width=1200),
        A.HorizontalFlip(p=0.5),
        A.GaussNoise(p=0.15),
        A.OneOf([
            A.MotionBlur(p=0.2),
            A.MedianBlur(blur_limit=3, p=0.1),
            A.Blur(blur_limit=3, p=0.1),
        ], p=0.2),
        A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, rotate_limit=12.5, p=0.4),
        A.OneOf([
            A.CLAHE(clip_limit=2),
            A.IAASharpen(),
            A.IAAEmboss(),
            A.RandomBrightnessContrast(),            
        ], p=0.3),
        A.HueSaturationValue(p=0.2),
        A.Normalize()
    ])

no_transforms = A.Compose([
        A.RandomCrop(height=150, width=1200),
        A.Normalize()
])

# %%
def min_max_scale(img):
    max_, min_ = img.max(), img.min()
    return (img - min_) / (max_ - min_)

# %%
aug = transforms(image=x)['image']
print(aug.shape)
plt.imshow(min_max_scale(aug))
# Out:
# (150, 1200, 3)

# %%
no_aug = no_transforms(image=x)['image']
print(no_aug.shape)
plt.imshow(min_max_scale(no_aug))
# Out:
# (150, 1200, 3)

# %%
class GeoDataset(Dataset):
    def __init__(self, df, transform=False):
        self.paths = [p for p in df.Path.values]
        self.transform = transform
        self.random_init()
        
    def random_init(self):
        self.random = np.random.randint(4, size=len(self.paths)) + 1
        
    def __len__(self):
        return len(self.paths)
    
    def __getitem__(self, idx):
        x, y = get_xy(self.paths[idx], MAPPING, self.random[idx])
        
        if self.transform:
            x = transforms(image=x)['image']
        else:
            x = no_transforms(image=x)['image']
        
        x = np.rollaxis(x, 2)
        return x, y

# %%
train_ds = GeoDataset(train, transform=True)
valid_ds = GeoDataset(val)
test_ds = GeoDataset(test)

# %%
x, y = train_ds[1]
x.shape, y
# Out:
# ((3, 150, 1200), 2)

# %% [markdown]
# ## Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        resnet = models.resnet18(pretrained=True)
        layers = list(resnet.children())[:8]
        self.features1 = nn.Sequential(*layers[:6])
        self.features2 = nn.Sequential(*layers[6:])
        self.classifier = nn.Sequential(nn.BatchNorm1d(512), nn.Linear(512, 128), nn.ReLU(), 
                                        nn.Dropout(0.4), nn.Linear(128, 3))
        self.dropout = nn.Dropout(0.4)
        
    def forward(self, x):
        x = self.features1(x)
        x = self.features2(x)
        x = F.relu(x)
        x = nn.AdaptiveAvgPool2d((1,1))(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(self.dropout(x))
        return x

# %%
def val_metrics(model, valid_dl):
    model.eval()
    total = 0
    sum_loss = 0
    correct = 0 
    with torch.no_grad():
        for x, y in valid_dl:
            batch = y.shape[0]
            x = x.cuda().float()
            y = y.cuda()
            out = model(x)
            loss = F.cross_entropy(out, y, reduction='sum')
            _, pred = torch.max(out, 1)
            correct += pred.eq(y).sum().item()
            sum_loss += loss.item()
            total += batch
    return sum_loss/total, correct/total

# %%
def train_epochs(model, train_dl, valid_dl, max_lr=0.001, epochs=10):
    idx = 0
    iterations = epochs*len(train_dl)
    pbar = tqdm(total=iterations)
    lrs = get_cosine_triangular_lr(max_lr, iterations)
    optimizer = create_optimizer2(model, lrs[0])
    scaler = GradScaler()
    prev_val_acc = 0.0
    path = ''
    for i in range(epochs):
        model.train()
        total = 0
        sum_loss = 0
        for x, y in train_dl:
            lr = lrs[idx]
            update_optimizer2(optimizer, [lr/25, lr/10, lr])
            batch = y.shape[0]
            x = x.cuda()
            y = y.cuda()
            out = model(x)
            loss = F.cross_entropy(out, y, reduction='sum')
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total += batch
            sum_loss += loss.item()
            idx += 1
            pbar.update()
        train_loss = sum_loss/total
        val_loss, val_acc = val_metrics(model, valid_dl)
        print("train_loss %.3f val_loss %.3f val_acc %.3f" % (train_loss, val_loss, val_acc))
        if val_acc > prev_val_acc: 
            prev_val_acc = val_acc
            if val_acc > 0.75:
                path = "../data/models/model_resnet18_stitch__wrap_loss_{0:.0f}.pth".format(100*val_acc)
                save_model(model, path)
                print(path)
    return path

# %%
def save_model(m, p): torch.save(m.state_dict(), p)
    
def load_model(m, p): m.load_state_dict(torch.load(p))

# %%
def cosine_segment(start_lr, end_lr, iterations):
    i = np.arange(iterations)
    c_i = 1 + np.cos(i*np.pi/iterations)
    return end_lr + (start_lr - end_lr)/2 *c_i

def get_cosine_triangular_lr(max_lr, iterations):
    min_start, min_end = max_lr/25, max_lr/(25*1e4)
    iter1 = int(0.3*iterations)
    iter2 = iterations - iter1
    segs = [cosine_segment(min_start, max_lr, iter1), cosine_segment(max_lr, min_end, iter2)]
    return np.concatenate(segs)

# %%
def create_optimizer2(model, lr0):
    params = [{'params': model.features1.parameters(), 'lr': lr0/20},
              {'params': model.features2.parameters(), 'lr': lr0/10},
              {'params': model.classifier.parameters(), 'lr': lr0}]
    return optim.Adam(params, weight_decay=9e-5)

def update_optimizer2(optimizer, group_lrs):
    for i, param_group in enumerate(optimizer.param_groups):
        param_group["lr"] = group_lrs[i]

# %%
batch_size = 64
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_dl = DataLoader(valid_ds, batch_size=batch_size)
test_dl = DataLoader(test_ds, batch_size=batch_size)

# %%
model = Net().cuda()

# %%
val_metrics(model, valid_dl)
# Out:
# (1.1273540623982747, 0.29)

# %%
best_path = train_epochs(model, train_dl, valid_dl, max_lr=0.00075, epochs=40)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1520.0), HTML(value='')))
# train_loss 1.123 val_loss 1.090 val_acc 0.363
# train_loss 1.097 val_loss 1.046 val_acc 0.527
# train_loss 1.045 val_loss 0.991 val_acc 0.570
# train_loss 0.976 val_loss 0.898 val_acc 0.620
# train_loss 0.902 val_loss 0.827 val_acc 0.647
# train_loss 0.833 val_loss 0.812 val_acc 0.650
# train_loss 0.781 val_loss 0.706 val_acc 0.727
# train_loss 0.698 val_loss 0.690 val_acc 0.710
# train_loss 0.638 val_loss 0.694 val_acc 0.700
# train_loss 0.587 val_loss 0.683 val_acc 0.710
# train_loss 0.519 val_loss 0.654 val_acc 0.723
# train_loss 0.479 val_loss 0.739 val_acc 0.737
# train_loss 0.425 val_loss 0.810 val_acc 0.703
# train_loss 0.403 val_loss 0.744 val_acc 0.717
# train_loss 0.359 val_loss 1.101 val_acc 0.707
# train_loss 0.350 val_loss 1.202 val_acc 0.667
# train_loss 0.274 val_loss 0.867 val_acc 0.730
# train_loss 0.294 val_loss 0.894 val_acc 0.727
# train_loss 0.271 val_loss 0.797 val_acc 0.730
# train_loss 0.207 val_loss 0.796 val_acc 0.737
# train_loss 0.207 val_loss 0.875 val_acc 0.753
# ../data/models/model_resnet18_stitch__wrap_loss_75.pth
# train_loss 0.201 val_loss 0.816 val_acc 0.760
# ../data/models/model_resnet18_stitch__wrap_loss_76.pth
# train_loss 0.173 val_loss 1.165 val_acc 0.713
# train_loss 0.156 val_loss 1.012 val_acc 0.737
# train_loss 0.156 val_loss 0.931 val_acc 0.743
# train_loss 0.150 val_loss 1.022 val_acc 0.753
# train_loss 0.155 val_loss 0.945 val_acc 0.750
# train_loss 0.135 val_loss 0.921 val_acc 0.740
# train_loss 0.107 val_loss 0.941 val_acc 0.747
# train_loss 0.102 val_loss 0.946 val_acc 0.760
# train_loss 0.086 val_loss 0.983 val_acc 0.757
# train_loss 0.093 val_loss 0.975 val_acc 0.753
# train_loss 0.093 val_loss 0.936 val_acc 0.750
# train_loss 0.094 val_loss 1.021 val_acc 0.737
# train_loss 0.087 val_loss 0.951 val_acc 0.753
# train_loss 0.085 val_loss 0.974 val_acc 0.743
# train_loss 0.100 val_loss 1.024 val_acc 0.750
# train_loss 0.105 val_loss 1.017 val_acc 0.753
# train_loss 0.083 val_loss 1.113 val_acc 0.730
# train_loss 0.090 val_loss 0.990 val_acc 0.763
# ../data/models/model_resnet18_stitch__wrap_loss_76.pth

# %% [markdown]
# ## Test Set Evaluation

# %%
best_model = Net().cuda()
load_model(best_model, best_path)

# %%
test.head()
# Out:
#      Country   Latitude  Longitude                 Pano_Id  \
# 1454  France  48.279493  -3.279190  JXrmMZJcpYcCxOrponoIfg
# 2079   Italy  39.904569  16.417789  HT1CeHVmqJGw1r4njqvTtw
# 2132   Italy  45.462391   8.387343  SX0H__5IC79fO3QAiBND_A
# 591    Spain  39.910727  -0.220675  xI3EK6TyZ7FOlCtFSF9FHQ
# 948    Spain  43.132019  -4.874817  ZwnagP_esswKtXPsNreclw
#
#                           Path
# 1454  data/images/France/0454/
# 2079   data/images/Italy/0079/
# 2132   data/images/Italy/0132/
# 591    data/images/Spain/0591/
# 948    data/images/Spain/0948/

# %%
rev_map = {v: k for k,v in MAPPING.items()}
rev_map
# Out:
# {0: 'Spain', 1: 'France', 2: 'Italy'}

# %%
preds = []
with torch.no_grad():
    best_model.eval()
    for x, y in test_dl:
        out = best_model(x.cuda().float())
        _, pred = torch.max(out, 1)
        pred = pred.cpu().detach().numpy()
        preds += [rev_map[p] for p in pred]

# %%
test['predictions'] = preds

# %%
sns.scatterplot(x='Longitude', y='Latitude', data=test, hue='predictions')

# %%
(test.Country == test.predictions).sum() / len(test)
# Out:
# 0.7566666666666667
