# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None

from PIL import Image
from pathlib import Path
from matplotlib.patches import Rectangle
from scipy.io import loadmat
import cv2
import torch
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
import random
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns
import albumentations as A
from tqdm.notebook import tqdm

# %% [markdown]
# ## Load DataFrame with Pathing

# %%
df = pd.read_csv('../data/POC_imagedata.csv')

# %%
df.head()
# Out:
#   Country   Latitude  Longitude                 Pano_Id  \
# 0   Spain  36.477286  -5.880578  mnPCQWYwG-MIUV64ybl23g
# 1   Spain  37.600117  -4.341563  cXqaOBEMHANps9ZENoLozw
# 2   Spain  42.870488  -1.381516  RHuZZGXpb4levD1LK8Wtsw
# 3   Spain  41.296693  -3.603524  si-40KyaaKHFGdvy12nSIg
# 4   Spain  39.024927  -3.977601  wniI8AxaJ2gBC7q1GjV7GQ
#
#                       Path
# 0  data/images/Spain/0000/
# 1  data/images/Spain/0001/
# 2  data/images/Spain/0002/
# 3  data/images/Spain/0003/
# 4  data/images/Spain/0004/

# %%
#df = df.sample(1000)

# %%
Image.open('../' + df.Path.iloc[0] + 'N.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x200 at 0x7F7358FA9160>

# %% [markdown]
# ## Create Train / Validation Sets

# %%
train, val = train_test_split(df, test_size=0.20, stratify=df.Country.values)
val, test = train_test_split(val, test_size=0.5, stratify=val.Country.values)

# %%
train.shape, val.shape, test.shape
# Out:
# ((2400, 5), (300, 5), (300, 5))

# %%
sns.scatterplot(x='Longitude', y='Latitude', data=val, hue='Country')

# %% [markdown]
# ## Dataset

# %%
MAPPING = {'Spain': 0, # Spain
           'France': 1, # France
           'Italy': 2} # Italy

# %%
def img_to_np(fullpath):
    x = cv2.imread(fullpath).astype(np.uint8)
    x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
    return x

# %%
def stitch_panos(path):
    return np.concatenate([img_to_np('../' + path + direction + '.jpg') for direction in 'NESW'], axis=1)

# %%
def get_xy(path, y_map):
    x = stitch_panos(path)
    y = y_map[path[12: 12 + path[12:].find('/')]]
    return x, y

# %%
x, y = get_xy(train.Path.iloc[0], MAPPING)

# %%
plt.imshow(x)

# %%
x.shape, y
# Out:
# ((200, 1200, 3), 0)

# %% [markdown]
# #### Data Augmentation Functions

# %%
transforms = A.Compose([
        A.RandomCrop(height=150, width=900),
        A.HorizontalFlip(p=0.5),
        A.GaussNoise(p=0.15),
        A.OneOf([
            A.MotionBlur(p=0.2),
            A.MedianBlur(blur_limit=3, p=0.1),
            A.Blur(blur_limit=3, p=0.1),
        ], p=0.2),
        A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, rotate_limit=22.5, p=0.25),
        A.OneOf([
            A.CLAHE(clip_limit=2),
            A.IAASharpen(),
            A.IAAEmboss(),
            A.RandomBrightnessContrast(),            
        ], p=0.3),
        A.HueSaturationValue(p=0.3),
        A.Normalize()
    ])

no_transforms = A.Compose([
        A.CenterCrop(height=150, width=900),
        A.Normalize()
])

# %%
def min_max_scale(img):
    max_, min_ = img.max(), img.min()
    return (img - min_) / (max_ - min_)

# %%
aug = transforms(image=x)['image']
print(aug.shape)
plt.imshow(min_max_scale(aug))
# Out:
# (150, 900, 3)

# %%
no_aug = no_transforms(image=x)['image']
print(no_aug.shape)
plt.imshow(min_max_scale(no_aug))
# Out:
# (150, 900, 3)

# %%
class GeoDataset(Dataset):
    def __init__(self, df, transform=False):
        self.paths = [p for p in df.Path.values]
        self.transform = transform
        
    def __len__(self):
        return len(self.paths)
    
    def __getitem__(self, idx):
        x, y = get_xy(self.paths[idx], MAPPING)
        
        if self.transform:
            x = transforms(image=x)['image']
        else:
            x = no_transforms(image=x)['image']
        
        x = np.rollaxis(x, 2)
        return x, y

# %%
train_ds = GeoDataset(train, transform=True)
valid_ds = GeoDataset(val)
test_ds = GeoDataset(test)

# %%
x, y = train_ds[1]
x.shape, y
# Out:
# ((3, 150, 900), 2)

# %% [markdown]
# ## Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        resnet = models.resnet18(pretrained=True)
        layers = list(resnet.children())[:8]
        self.features1 = nn.Sequential(*layers[:6])
        self.features2 = nn.Sequential(*layers[6:])
        self.classifier = nn.Sequential(nn.BatchNorm1d(512), nn.Linear(512, 128), nn.ReLU(), 
                                        nn.Dropout(), nn.Linear(128, 3))
        self.dropout = nn.Dropout()
        
    def forward(self, x):
        x = self.features1(x)
        x = self.features2(x)
        x = F.relu(x)
        x = nn.AdaptiveAvgPool2d((1,1))(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(self.dropout(x))
        return x

# %%
def val_metrics(model, valid_dl):
    model.eval()
    total = 0
    sum_loss = 0
    correct = 0 
    for x, y in valid_dl:
        batch = y.shape[0]
        x = x.cuda().float()
        y = y.cuda()
        out = model(x)
        loss = F.cross_entropy(out, y, reduction='sum')
        _, pred = torch.max(out, 1)
        correct += pred.eq(y).sum().item()
        sum_loss += loss.item()
        total += batch
    return sum_loss/total, correct/total

# %%
def train_epochs(model, train_dl, valid_dl, max_lr=0.001, epochs=10):
    idx = 0
    iterations = epochs*len(train_dl)
    pbar = tqdm(total=iterations)
    lrs = get_cosine_triangular_lr(max_lr, iterations)
    optimizer = create_optimizer2(model, lrs[0])
    prev_val_acc = 0.0
    for i in range(epochs):
        model.train()
        total = 0
        sum_loss = 0
        for x, y in train_dl:
            lr = lrs[idx]
            update_optimizer2(optimizer, [lr/50, lr/20, lr])
            batch = y.shape[0]
            x = x.cuda().float()
            y = y.cuda()
            out = model(x)
            loss = F.cross_entropy(out, y, reduction='sum')
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total += batch
            sum_loss += loss.item()
            idx += 1
            pbar.update()
        train_loss = sum_loss/total
        val_loss, val_acc = val_metrics(model, valid_dl)
        print("train_loss %.3f val_loss %.3f val_acc %.3f" % (train_loss, val_loss, val_acc))
        if val_acc > prev_val_acc: 
            prev_val_acc = val_acc
            if val_acc > 0.75:
                path = "../data/models/model_resnet18_stitch_loss_{0:.0f}.pth".format(100*val_acc)
                save_model(model, path)
                print(path)
    return path

# %%
def save_model(m, p): torch.save(m.state_dict(), p)
    
def load_model(m, p): m.load_state_dict(torch.load(p))

# %%
def cosine_segment(start_lr, end_lr, iterations):
    i = np.arange(iterations)
    c_i = 1 + np.cos(i*np.pi/iterations)
    return end_lr + (start_lr - end_lr)/2 *c_i

def get_cosine_triangular_lr(max_lr, iterations):
    min_start, min_end = max_lr/25, max_lr/(25*1e4)
    iter1 = int(0.3*iterations)
    iter2 = iterations - iter1
    segs = [cosine_segment(min_start, max_lr, iter1), cosine_segment(max_lr, min_end, iter2)]
    return np.concatenate(segs)

# %%
def create_optimizer2(model, lr0):
    params = [{'params': model.features1.parameters(), 'lr': lr0/50},
              {'params': model.features2.parameters(), 'lr': lr0/20},
              {'params': model.classifier.parameters(), 'lr': lr0}]
    return optim.Adam(params, weight_decay=2e-5)

def update_optimizer2(optimizer, group_lrs):
    for i, param_group in enumerate(optimizer.param_groups):
        param_group["lr"] = group_lrs[i]

# %%
batch_size = 64
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
valid_dl = DataLoader(valid_ds, batch_size=batch_size)
test_dl = DataLoader(test_ds, batch_size=batch_size)

# %%
model = Net().cuda()

# %%
val_metrics(model, valid_dl)
# Out:
# (1.11830748240153, 0.33)

# %%
best_path = train_epochs(model, train_dl, valid_dl, max_lr=0.0008, epochs=30)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1140.0), HTML(value='')))
# train_loss 1.133 val_loss 1.073 val_acc 0.460
# train_loss 1.100 val_loss 1.039 val_acc 0.527
# train_loss 1.066 val_loss 0.977 val_acc 0.603
# train_loss 1.019 val_loss 0.881 val_acc 0.590
# train_loss 0.942 val_loss 0.788 val_acc 0.633
# train_loss 0.897 val_loss 0.741 val_acc 0.640
# train_loss 0.831 val_loss 0.736 val_acc 0.670
# train_loss 0.796 val_loss 0.697 val_acc 0.673
# train_loss 0.741 val_loss 0.661 val_acc 0.700
# train_loss 0.713 val_loss 0.636 val_acc 0.723
# train_loss 0.666 val_loss 0.610 val_acc 0.737
# train_loss 0.626 val_loss 0.599 val_acc 0.763
# ../data/models/model_resnet18_stitch_loss_76.pth
# train_loss 0.601 val_loss 0.642 val_acc 0.723
# train_loss 0.582 val_loss 0.616 val_acc 0.757
# train_loss 0.528 val_loss 0.589 val_acc 0.773
# ../data/models/model_resnet18_stitch_loss_77.pth
# train_loss 0.497 val_loss 0.578 val_acc 0.763
# train_loss 0.506 val_loss 0.587 val_acc 0.787
# ../data/models/model_resnet18_stitch_loss_79.pth
# train_loss 0.451 val_loss 0.561 val_acc 0.770
# train_loss 0.426 val_loss 0.600 val_acc 0.783
# train_loss 0.391 val_loss 0.593 val_acc 0.780
# train_loss 0.404 val_loss 0.601 val_acc 0.767
# train_loss 0.369 val_loss 0.620 val_acc 0.780
# train_loss 0.357 val_loss 0.623 val_acc 0.787
# train_loss 0.340 val_loss 0.598 val_acc 0.790
# ../data/models/model_resnet18_stitch_loss_79.pth
# train_loss 0.351 val_loss 0.600 val_acc 0.797
# ../data/models/model_resnet18_stitch_loss_80.pth
# train_loss 0.328 val_loss 0.605 val_acc 0.793
# train_loss 0.328 val_loss 0.605 val_acc 0.793
# train_loss 0.309 val_loss 0.608 val_acc 0.793
# train_loss 0.325 val_loss 0.610 val_acc 0.793
# train_loss 0.329 val_loss 0.600 val_acc 0.797

# %% [markdown]
# ## Prediction Evaluation

# %%
best_model = Net().cuda()
load_model(best_model, best_path)

# %%
test.head()
# Out:
#      Country   Latitude  Longitude                 Pano_Id  \
# 135    Spain  38.026277  -3.256917  z9AW_FnHWgex3Xda2nTxsw
# 184    Spain  40.192256  -4.768169  YOsUc-qGEYnGG1esD7ZO-w
# 2574   Italy  45.767212   9.139545  OlHABSwXGB6lqy8BR5OLug
# 38     Spain  40.417505  -5.361720  _g9DyAkj9Cm4BZCFMAYepA
# 1281  France  50.254369   1.858271  aNH4gmccINVY27p-kwlohw
#
#                           Path
# 135    data/images/Spain/0135/
# 184    data/images/Spain/0184/
# 2574   data/images/Italy/0574/
# 38     data/images/Spain/0038/
# 1281  data/images/France/0281/

# %%
rev_map = {v: k for k,v in MAPPING.items()}
rev_map
# Out:
# {0: 'Spain', 1: 'France', 2: 'Italy'}

# %%
preds = []
with torch.no_grad():
    best_model.eval()
    for x, y in test_dl:
        out = best_model(x.cuda().float())
        _, pred = torch.max(out, 1)
        pred = pred.cpu().detach().numpy()
        preds += [rev_map[p] for p in pred]

# %%
test['predictions'] = preds

# %%
sns.scatterplot(x='Longitude', y='Latitude', data=test, hue='predictions')

# %%
(test.Country == test.predictions).sum() / len(test)
# Out:
# 0.71
